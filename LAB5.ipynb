# %% [markdown]
# <a href="https://colab.research.google.com/github/anwarnoor9876-png/ML_Lab/blob/main/LAB5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Seed_Data.csv')
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1098/343848936.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('Seed_Data.csv')
#       2 display(df.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# Apply Descriptive Stats to summarise the dataset

# %%
display(df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/3242353474.py in <cell line: 0>()
# ----> 1 display(df.describe())
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import StandardScaler

# Separate features (X) and target (y)
X = df.drop('target', axis=1)
y = df['target']

# Identify numerical features to scale
# Assuming all features except 'target' are numerical for this dataset
numerical_features = X.columns

# Initialize the StandardScaler
scaler = StandardScaler()

# Apply scaling to the numerical features
X_scaled = scaler.fit_transform(X)

# Convert the scaled features back to a DataFrame for better readability and future use
X_scaled_df = pd.DataFrame(X_scaled, columns=numerical_features)

display(X_scaled_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/363005381.py in <cell line: 0>()
#       2
#       3 # Separate features (X) and target (y)
# ----> 4 X = df.drop('target', axis=1)
#       5 y = df['target']
#       6
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.2, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/1276891186.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.2, random_state=42)
#       4
#       5 print("Shape of X_train:", X_train.shape)
#
# NameError: name 'X_scaled_df' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression model
log_reg_model = LogisticRegression(random_state=42, solver='liblinear') # Added solver for binary classification

# Train the model using the training data
log_reg_model.fit(X_train, y_train)

print("Logistic Regression model trained successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/3314320490.py in <cell line: 0>()
#       5
#       6 # Train the model using the training data
# ----> 7 log_reg_model.fit(X_train, y_train)
#       8
#       9 print("Logistic Regression model trained successfully.")
#
# NameError: name 'X_train' is not defined

# %%
y_pred = log_reg_model.predict(X_test)
print("Predictions made successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/493426137.py in <cell line: 0>()
# ----> 1 y_pred = log_reg_model.predict(X_test)
#       2 print("Predictions made successfully.")
#
# NameError: name 'X_test' is not defined

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Generate and print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Generate and print the confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/2531934654.py in <cell line: 0>()
#       3 # Generate and print the classification report
#       4 print("Classification Report:")
# ----> 5 print(classification_report(y_test, y_pred))
#       6
#       7 # Generate and print the confusion matrix
#
# NameError: name 'y_test' is not defined

# %%
df = pd.read_csv('USA_Housing.csv')
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1098/499212182.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('USA_Housing.csv')
#       2 display(df.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
print("First 5 rows of the dataset:")
display(df.head())

print("\nInformation about the dataset (data types and non-null values):")
df.info()

print("\nDescriptive statistics of the dataset:")
display(df.describe())
# Out:
# First 5 rows of the dataset:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/1640509963.py in <cell line: 0>()
#       1 print("First 5 rows of the dataset:")
# ----> 2 display(df.head())
#       3
#       4 print("\nInformation about the dataset (data types and non-null values):")
#       5 df.info()
#
# NameError: name 'df' is not defined

# %%
print("Missing values in each column:")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/518370820.py in <cell line: 0>()
#       1 print("Missing values in each column:")
# ----> 2 display(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %%
median_price = df['Price'].median()
df['High_Price'] = (df['Price'] > median_price).astype(int)
df = df.drop('Price', axis=1)

print("Value counts for High_Price:")
display(df['High_Price'].value_counts())

print("\nFirst 5 rows of the DataFrame with High_Price:")
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/406401481.py in <cell line: 0>()
# ----> 1 median_price = df['Price'].median()
#       2 df['High_Price'] = (df['Price'] > median_price).astype(int)
#       3 df = df.drop('Price', axis=1)
#       4
#       5 print("Value counts for High_Price:")
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
sns.histplot(df['Avg. Area Income'], bins=50, kde=True)
plt.title('Distribution of Avg. Area Income')
plt.xlabel('Avg. Area Income')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/3007746805.py in <cell line: 0>()
#       5
#       6 plt.figure(figsize=(8, 5))
# ----> 7 sns.histplot(df['Avg. Area Income'], bins=50, kde=True)
#       8 plt.title('Distribution of Avg. Area Income')
#       9 plt.xlabel('Avg. Area Income')
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
sns.histplot(df['Avg. Area House Age'], bins=50, kde=True)
plt.title('Distribution of Avg. Area House Age')
plt.xlabel('Avg. Area House Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/4094907045.py in <cell line: 0>()
#       5
#       6 plt.figure(figsize=(8, 5))
# ----> 7 sns.histplot(df['Avg. Area House Age'], bins=50, kde=True)
#       8 plt.title('Distribution of Avg. Area House Age')
#       9 plt.xlabel('Avg. Area House Age')
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
sns.histplot(df['Avg. Area Number of Rooms'], bins=50, kde=True)
plt.title('Distribution of Avg. Area Number of Rooms')
plt.xlabel('Avg. Area Number of Rooms')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/871430292.py in <cell line: 0>()
#       5
#       6 plt.figure(figsize=(8, 5))
# ----> 7 sns.histplot(df['Avg. Area Number of Rooms'], bins=50, kde=True)
#       8 plt.title('Distribution of Avg. Area Number of Rooms')
#       9 plt.xlabel('Avg. Area Number of Rooms')
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
sns.histplot(df['Area Population'], bins=50, kde=True)
plt.title('Distribution of Area Population')
plt.xlabel('Area Population')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/3456948466.py in <cell line: 0>()
#       5
#       6 plt.figure(figsize=(8, 5))
# ----> 7 sns.histplot(df['Area Population'], bins=50, kde=True)
#       8 plt.title('Distribution of Area Population')
#       9 plt.xlabel('Area Population')
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
sns.histplot(df['Avg. Area Number of Bedrooms'], bins=50, kde=True)
plt.title('Distribution of Avg. Area Number of Bedrooms')
plt.xlabel('Avg. Area Number of Bedrooms')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/1517466508.py in <cell line: 0>()
#       5
#       6 plt.figure(figsize=(8, 5))
# ----> 7 sns.histplot(df['Avg. Area Number of Bedrooms'], bins=50, kde=True)
#       8 plt.title('Distribution of Avg. Area Number of Bedrooms')
#       9 plt.xlabel('Avg. Area Number of Bedrooms')
#
# NameError: name 'df' is not defined

# %%
print()
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/3479517384.py in <cell line: 0>()
#       1 print()
#       2 plt.figure(figsize=(10, 8))
# ----> 3 sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
#       4 plt.title('Correlation Matrix of Features')
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import StandardScaler

# 1. Separate features (X) and target (y)
X = df.drop(['High_Price', 'Address'], axis=1)
y = df['High_Price']

# 2. Identify numerical features to scale
# All columns in X are numerical in this case after dropping 'Address' and 'High_Price'
numerical_features = X.columns

# 4. Initialize the StandardScaler
scaler = StandardScaler()

# 5. Apply scaling to the numerical features
X_scaled = scaler.fit_transform(X)

# 6. Convert the scaled features back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=numerical_features)

# 7. Display the first few rows of X_scaled_df
print("First 5 rows of scaled features (X_scaled_df):")
display(X_scaled_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/2827222843.py in <cell line: 0>()
#       2
#       3 # 1. Separate features (X) and target (y)
# ----> 4 X = df.drop(['High_Price', 'Address'], axis=1)
#       5 y = df['High_Price']
#       6
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.2, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1098/1276891186.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.2, random_state=42)
#       4
#       5 print("Shape of X_train:", X_train.shape)
#
# NameError: name 'X_scaled_df' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression model
log_reg_model = LogisticRegression(random_state=42, solver='liblinear')

# Train the model using the training data
log_reg_model.fit(X_train, y_train)

print("Logistic Regression model trained successfully.")
# Out:
# Logistic Regression model trained successfully.

# %%
y_pred = log_reg_model.predict(X_test)
print("Predictions made successfully.")
# Out:
# Predictions made successfully.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Generate and print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Generate and print the confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       479
#            1       0.91      0.90      0.91       521
#
#     accuracy                           0.91      1000
#    macro avg       0.90      0.91      0.90      1000
# weighted avg       0.91      0.91      0.91      1000
#
#
# Confusion Matrix:
# [[435  44]
#  [ 51 470]]
