# %% [markdown]
# <a href="https://colab.research.google.com/github/anwarnoor9876-png/ML_Lab/blob/main/Lab09_RF_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Random Forest applied to LendingClub data set
#
# For this exercise, we will be exploring publicly available data from [LendingClub.com](www.lendingclub.com). Lending Club connects people who need money (borrowers) with people who have money (investors). We try to create a model to predict the risk of lending money to someone given a wide range of credit related data. We will use lending data from 2007-2010 and be trying to classify and predict **whether or not the borrower paid back their loan in full.**
#
# Here are what the columns in the data set represent:
#
# * **credit.policy**: 1 if the customer meets the credit underwriting criteria of LendingClub.com, and 0 otherwise.
# * **purpose**: The purpose of the loan (takes values "credit_card", "debt_consolidation", "educational", "major_purchase", "small_business", and "all_other").
# * **int.rate**: The interest rate of the loan, as a proportion (a rate of 11% would be stored as 0.11). Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# * **installment**: The monthly installments owed by the borrower if the loan is funded.
# * **log.annual.inc**: The natural log of the self-reported annual income of the borrower.
# * **dti**: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# * **fico**: The FICO credit score of the borrower.
# * **days.with.cr.line**: The number of days the borrower has had a credit line.
# * **revol.bal**: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# * **revol.util**: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# * **inq.last.6mths**: The borrower's number of inquiries by creditors in the last 6 months.
# * **delinq.2yrs**: The number of times the borrower had been 30+ days past due on a payment in the past 2 years.
# * **pub.rec**: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).
# * **not.fully.paid**: The quantity of interest for classification - whether the borrower paid back the money in full or not

# %% [markdown]
# # Import Libraries and data set
#
# **Import the usual libraries for pandas and plotting**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Get the Data
#
# ** Use pandas to read loan_data.csv**

# %%
df = pd.read_csv('loan_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13504/2148904440.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('loan_data.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'loan_data.csv'

# %% [markdown]
# ### Check out the info(), head(), and describe() methods on loans

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/3771845804.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/3627053830.py in <cell line: 0>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/964094849.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
print("Follwoing is a breakup of credit approval status. 1 means approved credit, 0 means not approved.")
print(df['credit.policy'].value_counts())
# Out:
# Follwoing is a breakup of credit approval status. 1 means approved credit, 0 means not approved.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1574705963.py in <cell line: 0>()
#       1 print("Follwoing is a breakup of credit approval status. 1 means approved credit, 0 means not approved.")
# ----> 2 print(df['credit.policy'].value_counts())
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Histogram of FICO scores by credit approval status

# %%
df[df['credit.policy']==1]['fico'].plot.hist(bins=30,alpha=0.5,color='blue', label='Credit.Policy=1')
df[df['credit.policy']==0]['fico'].plot.hist(bins=30,alpha=0.5, color='red', label='Credit.Policy=0')
plt.legend(fontsize=15)
plt.title ("Histogram of FICO score by approved or disapproved credit policies", fontsize=16)
plt.xlabel("FICO score", fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1346882357.py in <cell line: 0>()
# ----> 1 df[df['credit.policy']==1]['fico'].plot.hist(bins=30,alpha=0.5,color='blue', label='Credit.Policy=1')
#       2 df[df['credit.policy']==0]['fico'].plot.hist(bins=30,alpha=0.5, color='red', label='Credit.Policy=0')
#       3 plt.legend(fontsize=15)
#       4 plt.title ("Histogram of FICO score by approved or disapproved credit policies", fontsize=16)
#       5 plt.xlabel("FICO score", fontsize=14)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Presence or absence of statistical difference of various factors between credit approval status

# %%
sns.boxplot(x=df['credit.policy'],y=df['int.rate'])
plt.title("Interest rate varies between risky and non-risky borrowers", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Interest rate",fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1546789211.py in <cell line: 0>()
# ----> 1 sns.boxplot(x=df['credit.policy'],y=df['int.rate'])
#       2 plt.title("Interest rate varies between risky and non-risky borrowers", fontsize=15)
#       3 plt.xlabel("Credit policy",fontsize=15)
#       4 plt.ylabel("Interest rate",fontsize=15)
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x=df['credit.policy'],y=df['log.annual.inc'])
plt.title("Income level does not make a big difference in credit approval odds", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Log. annual income",fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/622466614.py in <cell line: 0>()
# ----> 1 sns.boxplot(x=df['credit.policy'],y=df['log.annual.inc'])
#       2 plt.title("Income level does not make a big difference in credit approval odds", fontsize=15)
#       3 plt.xlabel("Credit policy",fontsize=15)
#       4 plt.ylabel("Log. annual income",fontsize=15)
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x=df['credit.policy'],y=df['days.with.cr.line'])
plt.title("Credit-approved users have a slightly higher days with credit line", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Days with credit line",fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/3696358300.py in <cell line: 0>()
# ----> 1 sns.boxplot(x=df['credit.policy'],y=df['days.with.cr.line'])
#       2 plt.title("Credit-approved users have a slightly higher days with credit line", fontsize=15)
#       3 plt.xlabel("Credit policy",fontsize=15)
#       4 plt.ylabel("Days with credit line",fontsize=15)
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x=df['credit.policy'],y=df['dti'])
plt.title("Debt-to-income level does not make a big difference in credit approval odds", fontsize=15)
plt.xlabel("Credit policy",fontsize=15)
plt.ylabel("Debt-to-income ratio",fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1862679539.py in <cell line: 0>()
# ----> 1 sns.boxplot(x=df['credit.policy'],y=df['dti'])
#       2 plt.title("Debt-to-income level does not make a big difference in credit approval odds", fontsize=15)
#       3 plt.xlabel("Credit policy",fontsize=15)
#       4 plt.ylabel("Debt-to-income ratio",fontsize=15)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Countplot of loans by purpose, with the color hue defined by not.fully.paid

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='purpose',hue='not.fully.paid',data=df, palette='Set1')
plt.title("Bar chart of loan purpose colored by not fully paid status", fontsize=17)
plt.xlabel("Purpose", fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/2289127717.py in <cell line: 0>()
#       1 plt.figure(figsize=(10,6))
# ----> 2 sns.countplot(x='purpose',hue='not.fully.paid',data=df, palette='Set1')
#       3 plt.title("Bar chart of loan purpose colored by not fully paid status", fontsize=17)
#       4 plt.xlabel("Purpose", fontsize=15)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Trend between FICO score and interest rate

# %%
sns.jointplot(x='fico',y='int.rate',data=df, color='purple', size=12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1299453461.py in <cell line: 0>()
# ----> 1 sns.jointplot(x='fico',y='int.rate',data=df, color='purple', size=12)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### lmplot to see if the trend differed between not.fully.paid and credit.policy

# %%
plt.figure(figsize=(14,7))
sns.lmplot(y='int.rate',x='fico',data=df,hue='credit.policy',
           col='not.fully.paid',palette='Set1',size=6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/171803513.py in <cell line: 0>()
#       1 plt.figure(figsize=(14,7))
# ----> 2 sns.lmplot(y='int.rate',x='fico',data=df,hue='credit.policy',
#       3            col='not.fully.paid',palette='Set1',size=6)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Setting up the Data
# ## Categorical Features
#
# The **purpose** column as categorical. We transform them using dummy variables so sklearn will be able to understand them.

# %%
df_final = pd.get_dummies(df,['purpose'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/669521864.py in <cell line: 0>()
# ----> 1 df_final = pd.get_dummies(df,['purpose'],drop_first=True)
#
# NameError: name 'df' is not defined

# %%
df_final.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/665224516.py in <cell line: 0>()
# ----> 1 df_final.head()
#
# NameError: name 'df_final' is not defined

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X = df_final.drop('not.fully.paid',axis=1)
y = df_final['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/650076426.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X = df_final.drop('not.fully.paid',axis=1)
#       3 y = df_final['not.fully.paid']
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
#
# NameError: name 'df_final' is not defined

# %%
X.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1716939484.py in <cell line: 0>()
# ----> 1 X.head()
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## Training a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Create an instance of DecisionTreeClassifier() called dtree and fit it to the training data.**

# %%
dtree = DecisionTreeClassifier(criterion='gini',max_depth=None)

# %%
dtree.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1939968571.py in <cell line: 0>()
# ----> 1 dtree.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree
# **Create predictions from the test set and create a classification report and a confusion matrix.**

# %%
predictions = dtree.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/2412497339.py in <cell line: 0>()
# ----> 1 predictions = dtree.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/213323377.py in <cell line: 0>()
# ----> 1 print(classification_report(y_test,predictions))
#
# NameError: name 'y_test' is not defined

# %%
cm=confusion_matrix(y_test,predictions)
print(cm)
print ("Accuracy of prediction:",round((cm[0,0]+cm[1,1])/cm.sum(),3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/980080918.py in <cell line: 0>()
# ----> 1 cm=confusion_matrix(y_test,predictions)
#       2 print(cm)
#       3 print ("Accuracy of prediction:",round((cm[0,0]+cm[1,1])/cm.sum(),3))
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ## Training the Random Forest model
#
# Now its time to train our model!
#
# **Create an instance of the RandomForestClassifier class and fit it to our training data from the previous step.**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13504/1542427849.py in <cell line: 0>()
# ----> 1 rfc.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ## Predictions and Evaluation
#
# Let's predict off the y_test values and evaluate our model.
#
# ** Predict the class of not.fully.paid for the X_test data.**

# %%
rfc_pred = rfc.predict(X_test)

# %% [markdown]
# **Now create a classification report from the results. Do you get anything strange or some sort of warning?**

# %%
cr = classification_report(y_test,predictions)

# %%
print(cr)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.84      0.84      2394
#           1       0.24      0.25      0.24       480
#
# avg / total       0.75      0.74      0.74      2874

# %% [markdown]
# **Show the Confusion Matrix for the predictions.**

# %%
cm = confusion_matrix(y_test,rfc_pred)
print(cm)
# Out:
# [[2389    5]
#  [ 472    8]]

# %% [markdown]
# ### Running a loop with increasing number of trees in the random forest and checking accuracy of confusion matrix

# %% [markdown]
# **Criterion 'gini' or 'entropy'**

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=10,max_depth=None,criterion='gini')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (criterion: 'gini')", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=10,max_depth=None,criterion='entropy')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (criterion: 'entropy')", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)

# %% [markdown]
# **Fixing max tree depth**

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=10,max_depth=None,criterion='gini')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (max depth: None)", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=10,max_depth=5,criterion='gini')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (max depth: 5)", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)

# %% [markdown]
# **Minimum sample split criteria**

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=2,max_depth=None,criterion='gini')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (minimum sample split: 2)", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=20,max_depth=None,criterion='gini')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (minimum sample split: 20)", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)
